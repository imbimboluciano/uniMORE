# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # 1. Load the dataset wineQualityReds (consider the first column as the index)

# %%
# read_csv
data = pd.read_csv("../data/wineQualityReds.csv", index_col=0)
data
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 1               7.4             0.700         0.00             1.9      0.076
# 2               7.8             0.880         0.00             2.6      0.098
# 3               7.8             0.760         0.04             2.3      0.092
# 4              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1595            6.2             0.600         0.08             2.0      0.090
# 1596            5.9             0.550         0.10             2.2      0.062
# 1597            6.3             0.510         0.13             2.3      0.076
# 1598            5.9             0.645         0.12             2.0      0.075
# 1599            6.0             0.310         0.47             3.6      0.067
#
#       free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 1                    11.0                  34.0  0.99780  3.51       0.56
# 2                    25.0                  67.0  0.99680  3.20       0.68
# 3                    15.0                  54.0  0.99700  3.26       0.65
# 4                    17.0                  60.0  0.99800  3.16       0.58
# 5                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1595                 32.0                  44.0  0.99490  3.45       0.58
# 1596                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 29.0                  40.0  0.99574  3.42       0.75
# 1598                 32.0                  44.0  0.99547  3.57       0.71
# 1599                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1         9.4        5
# 2         9.8        5
# 3         9.8        5
# 4         9.8        6
# 5         9.4        5
# ...       ...      ...
# 1595     10.5        5
# 1596     11.2        6
# 1597     11.0        6
# 1598     10.2        5
# 1599     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# # 2. Split the dataset in train and test considering that the target column is called 'quality'

# %%
X = data.loc[:,'fixed.acidity':'alcohol']
y = data['quality']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 1132            5.9              0.19         0.21             1.7      0.045
# 504            10.5              0.26         0.47             1.9      0.078
# 1017            8.9              0.38         0.40             2.2      0.068
# 682             8.0              0.45         0.23             2.2      0.094
# 1156            8.3              0.60         0.25             2.2      0.118
# ...             ...               ...          ...             ...        ...
# 193             6.8              0.63         0.12             3.8      0.099
# 756             7.8              0.91         0.07             1.9      0.058
# 126             9.0              0.62         0.04             1.9      0.146
# 427             6.4              0.67         0.08             2.1      0.045
# 1258            7.0              0.58         0.28             4.8      0.085
#
#       free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 1132                 57.0                 135.0  0.99341  3.32       0.44
# 504                   6.0                  24.0  0.99760  3.18       1.04
# 1017                 12.0                  28.0  0.99486  3.27       0.75
# 682                  16.0                  29.0  0.99620  3.21       0.49
# 1156                  9.0                  38.0  0.99616  3.15       0.53
# ...                   ...                   ...      ...   ...        ...
# 193                  16.0                 126.0  0.99690  3.28       0.61
# 756                  22.0                  47.0  0.99525  3.51       0.43
# 126                  27.0                  90.0  0.99840  3.16       0.70
# 427                  19.0                  48.0  0.99490  3.49       0.49
# 1258                 12.0                  69.0  0.99633  3.32       0.70
#
#       alcohol
# 1132      9.5
# 504      10.9
# 1017     12.6
# 682      10.2
# 1156      9.8
# ...       ...
# 193       9.5
# 756      10.7
# 126       9.4
# 427      11.4
# 1258     11.0
#
# [1279 rows x 11 columns]

# %%
X_test
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  residual.sugar  chlorides  \
# 121             7.3             1.070         0.09             1.7      0.178
# 1020            7.0             0.500         0.14             1.8      0.078
# 1346            8.2             0.440         0.24             2.3      0.063
# 981             9.1             0.500         0.30             1.9      0.065
# 1083            7.2             0.380         0.30             1.8      0.073
# ...             ...               ...          ...             ...        ...
# 447            12.5             0.380         0.60             2.6      0.081
# 1275            7.8             0.580         0.13             2.1      0.102
# 1423            7.0             0.540         0.00             2.1      0.079
# 413             7.1             0.735         0.16             1.9      0.100
# 32              6.9             0.685         0.00             2.5      0.105
#
#       free.sulfur.dioxide  total.sulfur.dioxide  density    pH  sulphates  \
# 121                  10.0                  89.0  0.99620  3.30       0.57
# 1020                 10.0                  23.0  0.99636  3.53       0.61
# 1346                 10.0                  28.0  0.99613  3.25       0.53
# 981                   8.0                  17.0  0.99774  3.32       0.71
# 1083                 31.0                  70.0  0.99685  3.42       0.59
# ...                   ...                   ...      ...   ...        ...
# 447                  31.0                  72.0  0.99960  3.10       0.73
# 1275                 17.0                  36.0  0.99440  3.24       0.53
# 1423                 39.0                  55.0  0.99560  3.39       0.84
# 413                  15.0                  77.0  0.99660  3.27       0.64
# 32                   22.0                  37.0  0.99660  3.46       0.57
#
#       alcohol
# 121       9.0
# 1020     10.4
# 1346     10.2
# 981      10.5
# 1083      9.5
# ...       ...
# 447      10.5
# 1275     11.2
# 1423     11.4
# 413       9.3
# 32       10.6
#
# [320 rows x 11 columns]

# %% [markdown]
# # 3. Normalize train and test data

# %%
# StandardScaler + fit_transform
ss = StandardScaler()

newX_train = ss.fit_transform(X_train)
newX_test = ss.transform(X_test)

# %% [markdown]
# # 4. Create a RandomForest classifier with 300 estimators

# %%
# RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=300)
rfc
# Out:
# RandomForestClassifier(n_estimators=300)

# %% [markdown]
# # 5. Get the accuracy of the model in cross validation (with K=5)

# %%
scores = cross_val_score(rfc, newX_train, y_train, cv = 5)
print(scores)
scores.mean()
# Out:
# [0.6484375 0.7265625 0.7421875 0.6875    0.6745098]
# 0.6958394607843138

# %% [markdown]
# # 6. Apply in cross validation a GridSearch with the following parameters to be tested:
# - 'n_estimators': [100, 300, 500, 800, 1000],
# - 'criterion': ['gini', 'entropy'],
# - 'bootstrap': [True, False]

# %%
parameters = {'n_estimators':[100, 300, 500, 800, 1000], 
              'criterion':['gini', 'entropy'],
              'bootstrap':[True, False]
              }
clf = GridSearchCV(rfc, parameters, cv=5, n_jobs=-1)
clf.fit(newX_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(n_estimators=300),
#              n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'n_estimators': [100, 300, 500, 800, 1000]})

# %% [markdown]
# # 7. Indicate the configuration that generates the best accuracy

# %%
print(f'{clf.best_params_} -> accuracy: {clf.best_score_}')
# Out:
# {'bootstrap': True, 'criterion': 'gini', 'n_estimators': 800} -> accuracy: 0.7044270833333333

# %% [markdown]
# # 8. Create a pipeline with the the preprocessing component and the model component.

# %%
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# %%
my_pipeline = Pipeline(steps=[('preprocessing_transformer', ss),
                              ('model', RandomForestClassifier(n_estimators=clf.best_params_['n_estimators'], bootstrap=clf.best_params_['bootstrap'],
                                                               criterion=clf.best_params_['criterion']))], verbose = True)
my_pipeline
# Out:
# Pipeline(steps=[('preprocessing_transformer', StandardScaler()),
#                 ('model', RandomForestClassifier(n_estimators=800))],
#          verbose=True)

# %%
# Preprocessing of validation data, get predictions
my_pipeline.fit(X_train, y_train)
preds = my_pipeline.predict(X_test)
# Out:
# [Pipeline]  (step 1 of 2) Processing preprocessing_transformer, total=   0.0s
# [Pipeline] ............. (step 2 of 2) Processing model, total=   3.0s

# %%
# Evaluate the model
score = accuracy_score(y_test, preds)
print('Accuracy Score:', score)
# Out:
# Accuracy Score: 0.7125
